# %% [markdown]
# <style>
# .text_cell_render {
# font-family: Times New Roman, serif;
# }
# </style>

# %% [markdown]
# # Title Page
# <b> NAME OF PROJECT </b> : Palmer Archipelago (Antarctica) penguin data set cassification using supervised and unsupervised
# learning.<br>
# Prepared by : <br>
# <b> Abhishek Agarwala. </b> <br>
# <b> Tahsin Elahi Navin.</b> <br>

# %% [markdown]
# # Abstract
# In this project we used the Palmer Archipelago (Antarctica) penguin data set which is called the new Iris. Our project attempts
# to answer how
# well unsupervised learning like <b> K-Means and different variations of it </b> can perform for classification compared to
# traditional supervised learning methods such as <b> Logistic Regression </b> ,<b> Random Forest Classifier </b>. It is an
# alasysis on how unsupervised learning can work if a dataset is well-clustered.

# %% [markdown]
# # Table of Contents
# 1. Introduction <br>
#     a) Introduction to project <br>
#     b) Problem Statement <br>
#     c) Dataset <br>
#         i) Data Collection <br>
#         ii) Exploratory Data Analysis <br>
#         iii) Data preparation <br>
# 2. Methodology <br>
#     a) Method used <br>
#     b) Training details <br>
# 3. Experiments <br>
#     a) Results/Evaluation <br>
#     b) Error analysis <br>
#     c) Future work <br>
# 4. Conclusion <br>
# 5. Code <br>

# %% [markdown]
# # Introduction

# %% [markdown]
# # a)  Introduction to project
# The Palmer Archipelago (Antarctica) penguin dataset is extremely good for Clustering. So we tried to show that if a dataset can be well_clustered it may be possible to use unsupervised learning methods for classification by first CLustering the dataset. This was our motivation behind the project.

# %% [markdown]
# # b) Problem Statement
#  Palmer Archipelago (Antarctica) penguin data set is known for being a well clustered dataset. The dataset has a target feature known as Species which has 3 classes. These classes are 3 different penguin species. They are : <br>
# &emsp; <b> Adelie Penguin (Pygoscelis adeliae) </b> <br>
# &emsp; <b> Chinstrap penguin (Pygoscelis antarctica) </b> <br>
# &emsp; <b> Gentoo penguin (Pygoscelis papua) </b> <br>
# In this project we used the unsupervised learning <b>K-Means </b> method for <b>Clustering </b> and <b>Classification </b> and compared its results with traditional methods for <b>Classfication </b> such as <b>Logistic Regression, RandomForestClassifier </b>. The dataset is extremely good for Clustering. So we tried to show that if a dataset can be well_clustered it may be possible to use unsupervised learning methods for classification. This was our motivation behind the project.

# %% [markdown]
# # c) Datatset
# The dataset that we have used is known as the Palmer Archipelago (Antarctica) penguin data set

# %% [markdown]
# # i) Data Collection
# Data were collected and made available by Dr. Kristen Gorman and the Palmer Station, Antarctica LTER, a member of the Long Term Ecological Research Network. <br>
# It was collected as a means of ecological expeditions and to better study the penguins. <br>
# The reason we are using this dataset is because it is very good for <b> Clustering </b> <br>
# <br>
# This is the description of the features of our dataset:
# * <b>studyName</b> - Sampling expedition name from which data were collected, generated.
# * <b>Sample Number</b> - An integer denoting the continuous numbering sequence for each sample.
# * <b>Species</b> - Categorical variable for species of the penguin. There are 3 unique values. These are the target variables. They are <b> Adelie Penguin (Pygoscelis adeliae),Chinstrap penguin (Pygoscelis antarctica),Gentoo penguin (Pygoscelis papua).<\b>
# * <b>Region</b> - Categorical variable denoting the region of the penguins. It has only one unique value
# * <b>Island</b> - Categorical variable denoting the name of the islands where the penguins were residing. There are 3 unique vlaues.
# * <b>Stage</b> - Categrical variable denoting the reproductive stage of pengunins. It has only one unique value.
# * <b>Individual ID</b> - Categorical variable denoting the unique ID for the specific penguin. It has unique values for all penguins
# * <b>Clutch Completion</b> - Categorical variable denoting if the study nest observed with a full clutch, i.e., 2 eggs
# * <b>Culmen Length</b> - Integer variable denoting the length of the dorsal ridge of a bird's bill (millimeters)
# * <b>Culmen Depth</b> - Integer variable denoting the depth of the dorsal ridge of a bird's bill (millimeters)
# * <b>Flipper Length</b> - Integer variable denoting the length penguin flipper (millimeters)
# * <b>Body Mass</b> - Integer variable denoting the penguin body mass (grams)
# * <b>Sex</b> - Categorical variable denoting the gender of the penguins
# * <b>Delta 15 N (o/oo)</b> - Integer variable denoting the measure of the ratio of stable isotopes 15N:14N
# * <b>Delta 13 C (o/oo)</b> - Integer variable denoting the measure of the ratio of stable isotopes 13C:12C
# * <b>Comments</b> - A string with text providing additional relevant information for data

# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:\\Users\\hp\\Desktop\\penguins_lter.csv")
df.head()
df['Sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
df.describe()
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          342.000000         342.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.459584           1.974793
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.225000          15.600000
# 50%        58.000000           44.450000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           342.000000     342.000000         330.000000
# mean            200.915205    4201.754386           8.733382
# std              14.061714     801.954536           0.551770
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.299890
# 50%             197.000000    4050.000000           8.652405
# 75%             213.000000    4750.000000           9.172123
# max             231.000000    6300.000000          10.025440
#
#        Delta 13 C (o/oo)
# count         331.000000
# mean          -25.686292
# std             0.793961
# min           -27.018540
# 25%           -26.320305
# 50%           -25.833520
# 75%           -25.062050
# max           -23.787670

# %% [markdown]
# # ii) Exploratory Data Analysis

# %%
df.isnull().sum()
df['Sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %% [markdown]
# There are 2 approaches here. They are:
# * One is dropping the nan valued samples
# * Another is imputation with mode.

# %%
#Dropping
# df =df.dropna(axis=0)
# print(df.isnull().sum())

# %%
#Imputation
import warnings
warnings.filterwarnings('ignore')
columns=df.columns
for column in columns:
    df[column][~(df[column]==df[column])]=df[column].mode()[0]
df.shape
print(df.isnull().sum())
# Out:
# studyName              0
# Sample Number          0
# Species                0
# Region                 0
# Island                 0
# Stage                  0
# Individual ID          0
# Clutch Completion      0
# Date Egg               0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# Delta 15 N (o/oo)      0
# Delta 13 C (o/oo)      0
# Comments               0
# dtype: int64

# %%
print(df['Sex'].unique())
print(df['Sex'].value_counts())
df.loc[df['Sex']=='.','Sex']=df['Sex'].mode()[0]
print(df['Sex'].value_counts())
# Out:
# ['MALE' 'FEMALE' '.']
# MALE      178
# FEMALE    165
# .           1
# Name: Sex, dtype: int64
# MALE      179
# FEMALE    165
# Name: Sex, dtype: int64

# %%
# from sklearn.preprocessing import LabelEncoder
# new_df = df.copy()
# objList = new_df.select_dtypes(include = "object").columns
# print (objList)
# le = LabelEncoder()
# for feat in objList:
#     new_df[feat] = le.fit_transform(new_df[feat].astype(str))
# print(new_df.head())
# print(new_df.corrwith(new_df['Species']))
# new_df.corr()

# %% [markdown]
# # iii) Data Preparation

# %% [markdown]
# We need to transform the species categorical feature to numeric values. So we used <b> Label Encoder </b>

# %%
from sklearn.preprocessing import LabelEncoder
# print(type(dfreal[['Sex']].mode().values()))

labelencoder = LabelEncoder()
df['Species']=labelencoder.fit_transform(df['Species'])
df.head()
#df=dfreal.drop(['Species'],axis=1)
#dfreal2.head()
# Out:
#   studyName  Sample Number  Species  Region     Island               Stage  \
# 0   PAL0708              1        0  Anvers  Torgersen  Adult, 1 Egg Stage
# 1   PAL0708              2        0  Anvers  Torgersen  Adult, 1 Egg Stage
# 2   PAL0708              3        0  Anvers  Torgersen  Adult, 1 Egg Stage
# 3   PAL0708              4        0  Anvers  Torgersen  Adult, 1 Egg Stage
# 4   PAL0708              5        0  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Individual ID Clutch Completion  Date Egg  Culmen Length (mm)  \
# 0          N1A1               Yes  11/11/07                39.1
# 1          N1A2               Yes  11/11/07                39.5
# 2          N2A1               Yes  11/16/07                40.3
# 3          N2A2               Yes  11/16/07                41.1
# 4          N3A1               Yes  11/16/07                36.7
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 0               18.7                181.0         3750.0    MALE
# 1               17.4                186.0         3800.0  FEMALE
# 2               18.0                195.0         3250.0  FEMALE
# 3               17.0                190.0         3800.0    MALE
# 4               19.3                193.0         3450.0  FEMALE
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)                               Comments
# 0            7.63220          -27.01854         Not enough blood for isotopes.
# 1            8.94956          -24.69454  Nest never observed with full clutch.
# 2            8.36821          -25.33302  Nest never observed with full clutch.
# 3            7.63220          -27.01854                     Adult not sampled.
# 4            8.76651          -25.32426  Nest never observed with full clutch.

# %% [markdown]
# Some features are redundant as they have no significance and they add no correlation with the target variable. Those are: <br>
# &emsp;1. <b> studyName </b> <br>
# &emsp;2. <b> Sample Number </b> <br>
# &emsp;3. <b> Region </b> <br>
# &emsp;4. <b> Stage</b> <br>
# &emsp;5. <b> Individual ID </b> <br>
# &emsp;6. <b> Comments </b> <br>
# So we are dropping it

# %%
df=df.drop(['studyName','Sample Number','Region','Stage','Individual ID','Comments'],axis=1)
df.head()
# Out:
#    Species     Island Clutch Completion  Date Egg  Culmen Length (mm)  \
# 0        0  Torgersen               Yes  11/11/07                39.1
# 1        0  Torgersen               Yes  11/11/07                39.5
# 2        0  Torgersen               Yes  11/16/07                40.3
# 3        0  Torgersen               Yes  11/16/07                41.1
# 4        0  Torgersen               Yes  11/16/07                36.7
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 0               18.7                181.0         3750.0    MALE
# 1               17.4                186.0         3800.0  FEMALE
# 2               18.0                195.0         3250.0  FEMALE
# 3               17.0                190.0         3800.0    MALE
# 4               19.3                193.0         3450.0  FEMALE
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0            7.63220          -27.01854
# 1            8.94956          -24.69454
# 2            8.36821          -25.33302
# 3            7.63220          -27.01854
# 4            8.76651          -25.32426

# %% [markdown]
# **We now want to One-Hot encode the cateforical variables using dummy encoding. This often gives us better accuracy for categorical features**

# %%
clutch_feature=pd.get_dummies(df['Clutch Completion'],prefix='Clutch Completion',prefix_sep='_',drop_first=True)
df=df.drop(['Clutch Completion'],axis=1)
df= pd.concat([df,clutch_feature],axis=1)
df.head()
# Out:
#    Species     Island  Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0        0  Torgersen  11/11/07                39.1               18.7
# 1        0  Torgersen  11/11/07                39.5               17.4
# 2        0  Torgersen  11/16/07                40.3               18.0
# 3        0  Torgersen  11/16/07                41.1               17.0
# 4        0  Torgersen  11/16/07                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)     Sex  Delta 15 N (o/oo)  \
# 0                181.0         3750.0    MALE            7.63220
# 1                186.0         3800.0  FEMALE            8.94956
# 2                195.0         3250.0  FEMALE            8.36821
# 3                190.0         3800.0    MALE            7.63220
# 4                193.0         3450.0  FEMALE            8.76651
#
#    Delta 13 C (o/oo)  Clutch Completion_Yes
# 0          -27.01854                      1
# 1          -24.69454                      1
# 2          -25.33302                      1
# 3          -27.01854                      1
# 4          -25.32426                      1

# %%
print(df['Island'].unique())
# Out:
# ['Torgersen' 'Biscoe' 'Dream']

# %%
island_feature=pd.get_dummies(df['Island'],prefix='Island',prefix_sep='_',drop_first=True)
df=df.drop(['Island'],axis=1)
df=pd.concat([df,island_feature],axis=1)
df.head()
# Out:
#    Species  Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0        0  11/11/07                39.1               18.7
# 1        0  11/11/07                39.5               17.4
# 2        0  11/16/07                40.3               18.0
# 3        0  11/16/07                41.1               17.0
# 4        0  11/16/07                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)     Sex  Delta 15 N (o/oo)  \
# 0                181.0         3750.0    MALE            7.63220
# 1                186.0         3800.0  FEMALE            8.94956
# 2                195.0         3250.0  FEMALE            8.36821
# 3                190.0         3800.0    MALE            7.63220
# 4                193.0         3450.0  FEMALE            8.76651
#
#    Delta 13 C (o/oo)  Clutch Completion_Yes  Island_Dream  Island_Torgersen
# 0          -27.01854                      1             0                 1
# 1          -24.69454                      1             0                 1
# 2          -25.33302                      1             0                 1
# 3          -27.01854                      1             0                 1
# 4          -25.32426                      1             0                 1

# %%
sex_feature=pd.get_dummies(df['Sex'],prefix='Sex',prefix_sep='_',drop_first=True)
df=df.drop(['Sex'],axis=1)
df=pd.concat([df,sex_feature],axis=1)
df.head()
# Out:
#    Species  Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0        0  11/11/07                39.1               18.7
# 1        0  11/11/07                39.5               17.4
# 2        0  11/16/07                40.3               18.0
# 3        0  11/16/07                41.1               17.0
# 4        0  11/16/07                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0                181.0         3750.0            7.63220          -27.01854
# 1                186.0         3800.0            8.94956          -24.69454
# 2                195.0         3250.0            8.36821          -25.33302
# 3                190.0         3800.0            7.63220          -27.01854
# 4                193.0         3450.0            8.76651          -25.32426
#
#    Clutch Completion_Yes  Island_Dream  Island_Torgersen  Sex_MALE
# 0                      1             0                 1         1
# 1                      1             0                 1         0
# 2                      1             0                 1         0
# 3                      1             0                 1         1
# 4                      1             0                 1         0

# %% [markdown]
# **The Boxplot shows that there are no outliers in the dataset**

# %%
feature_columns=['Culmen Length (mm)','Culmen Depth (mm)','Flipper Length (mm)','Body Mass (g)','Delta 15 N (o/oo)','Delta 13 C (o/oo)']
df.boxplot(feature_columns, figsize = (20, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **We further show that there are no outliers in the dataset using z-score and standardization. if that value is less than -3 or greater than 3 then it is considered as an outlier**

# %%
#Standardization for outlier checking

columnsnew=['C1','C2','F1','BM','D1','D2']
datafram=pd.DataFrame(columns=columnsnew)
i=0
for col in feature_columns:
    datafram[columnsnew[i]]=(df[col]-df[col].mean())/(df[col].std())
    i=i+1
datafram.head()
sm=0
for col in columnsnew:
    sm+=((datafram[col]<-3)|(datafram[col]>3)).sum()
print(sm)
# Out:
# 0

# %% [markdown]
# **As the feature values differ widely from each other we need to use scaling. We have used Standardization as it is almost always applicable and the most preferred form of scaling**

# %%
for column in feature_columns:
    df[column]=(df[column]-df[column].mean())/(df[column].std())
df.head()
# Out:
#    Species  Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0        0  11/11/07           -0.882090           0.787030
# 1        0  11/11/07           -0.808667           0.126816
# 2        0  11/16/07           -0.661821           0.431530
# 3        0  11/16/07           -0.514975          -0.076326
# 4        0  11/16/07           -1.322628           1.091743
#
#    Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0            -1.413412      -0.561634          -1.812977          -1.564680
# 1            -1.057420      -0.499150           0.447928           1.271977
# 2            -0.416635      -1.186480          -0.549808           0.492653
# 3            -0.772626      -0.499150          -1.812977          -1.564680
# 4            -0.559031      -0.936542           0.133770           0.503346
#
#    Clutch Completion_Yes  Island_Dream  Island_Torgersen  Sex_MALE
# 0                      1             0                 1         1
# 1                      1             0                 1         0
# 2                      1             0                 1         0
# 3                      1             0                 1         1
# 4                      1             0                 1         0

# %% [markdown]
# **Here pairplot shows the correlation of all the numeric features with each other**

# %%
import seaborn as sns
feature_columns_new= feature_columns.copy()
feature_columns_new.append('Species')
print(feature_columns)
sns.pairplot(df[feature_columns_new],hue='Species')
# Out:
# ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']

# %% [markdown]
# **We can see that Body Mass (g) and Flipper Length (mm) are highly correlated**

# %%
print(df[feature_columns_new].corr())
# Out:
#                      Culmen Length (mm)  Culmen Depth (mm)  \
# Culmen Length (mm)             1.000000          -0.234635
# Culmen Depth (mm)             -0.234635           1.000000
# Flipper Length (mm)            0.656856          -0.582472
# Body Mass (g)                  0.595720          -0.471339
# Delta 15 N (o/oo)             -0.006961           0.511599
# Delta 13 C (o/oo)              0.224159           0.373120
# Species                        0.727832          -0.741363
#
#                      Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# Culmen Length (mm)              0.656856       0.595720          -0.006961
# Culmen Depth (mm)              -0.582472      -0.471339           0.511599
# Flipper Length (mm)             1.000000       0.871302          -0.398915
# Body Mass (g)                   0.871302       1.000000          -0.454298
# Delta 15 N (o/oo)              -0.398915      -0.454298           1.000000
# Delta 13 C (o/oo)              -0.295225      -0.320374           0.597626
# Species                         0.849256       0.746913          -0.384804
#
#                      Delta 13 C (o/oo)   Species
# Culmen Length (mm)            0.224159  0.727832
# Culmen Depth (mm)             0.373120 -0.741363
# Flipper Length (mm)          -0.295225  0.849256
# Body Mass (g)                -0.320374  0.746913
# Delta 15 N (o/oo)             0.597626 -0.384804
# Delta 13 C (o/oo)             1.000000 -0.134142
# Species                      -0.134142  1.000000

# %% [markdown]
# **We can see that Body Mass and Flipper Length are highly correlated. So we drop Body Mass as its correlation value is lesser than Flipper Length for Species which is our target variable**

# %%
df.drop(['Body Mass (g)'],axis=1)
df.head()
# Out:
#    Species  Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0        0  11/11/07           -0.882090           0.787030
# 1        0  11/11/07           -0.808667           0.126816
# 2        0  11/16/07           -0.661821           0.431530
# 3        0  11/16/07           -0.514975          -0.076326
# 4        0  11/16/07           -1.322628           1.091743
#
#    Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0            -1.413412      -0.561634          -1.812977          -1.564680
# 1            -1.057420      -0.499150           0.447928           1.271977
# 2            -0.416635      -1.186480          -0.549808           0.492653
# 3            -0.772626      -0.499150          -1.812977          -1.564680
# 4            -0.559031      -0.936542           0.133770           0.503346
#
#    Clutch Completion_Yes  Island_Dream  Island_Torgersen  Sex_MALE
# 0                      1             0                 1         1
# 1                      1             0                 1         0
# 2                      1             0                 1         0
# 3                      1             0                 1         1
# 4                      1             0                 1         0

# %% [markdown]
# **Here Date Egg is a datatime variable. So lets extract the month of the variable as a part of feature engineering and see the values of that feature**

# %%
datemonth=pd.DatetimeIndex(df['Date Egg']).month
print(datemonth.unique())
print(datemonth.value_counts())
# Out:
# Int64Index([11, 12], dtype='int64', name='Date Egg')
# 11    330
# 12     14
# Name: Date Egg, dtype: int64

# %% [markdown]
# **As we can see 11th month dominates the other value which is 12th. So we can drop this feature too.**

# %%
df=df.drop(['Date Egg'],axis=1)
df.head(5)
# Out:
#    Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0        0           -0.882090           0.787030            -1.413412
# 1        0           -0.808667           0.126816            -1.057420
# 2        0           -0.661821           0.431530            -0.416635
# 3        0           -0.514975          -0.076326            -0.772626
# 4        0           -1.322628           1.091743            -0.559031
#
#    Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  Clutch Completion_Yes  \
# 0      -0.561634          -1.812977          -1.564680                      1
# 1      -0.499150           0.447928           1.271977                      1
# 2      -1.186480          -0.549808           0.492653                      1
# 3      -0.499150          -1.812977          -1.564680                      1
# 4      -0.936542           0.133770           0.503346                      1
#
#    Island_Dream  Island_Torgersen  Sex_MALE
# 0             0                 1         1
# 1             0                 1         0
# 2             0                 1         0
# 3             0                 1         1
# 4             0                 1         0

# %% [markdown]
# **As we can see 11th month dominates the other value which is 12th. So we can drop this feature too.**

# %%
target=df[['Species']]
df=df.drop(['Species'],axis=1)
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0           -0.882090           0.787030            -1.413412      -0.561634
# 1           -0.808667           0.126816            -1.057420      -0.499150
# 2           -0.661821           0.431530            -0.416635      -1.186480
# 3           -0.514975          -0.076326            -0.772626      -0.499150
# 4           -1.322628           1.091743            -0.559031      -0.936542
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)  Clutch Completion_Yes  Island_Dream  \
# 0          -1.812977          -1.564680                      1             0
# 1           0.447928           1.271977                      1             0
# 2          -0.549808           0.492653                      1             0
# 3          -1.812977          -1.564680                      1             0
# 4           0.133770           0.503346                      1             0
#
#    Island_Torgersen  Sex_MALE
# 0                 1         1
# 1                 1         0
# 2                 1         0
# 3                 1         1
# 4                 1         0

# %% [markdown]
# # Methodology

# %% [markdown]
# # Method used
# For Classification: <br>
# &emsp;1. <b>Supervised Learning:</b><br>
# &emsp;&emsp;a.<b>Logistic Regression</b><br>
# &emsp;&emsp;b.<b>RandomForestClassifier</b><br>
# &emsp;2. <b>Unsupervised Learning:</b><br>
# &emsp;&emsp;a.<b>K-Means</b><br>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Logistic Regression

# %%
X_trainreal,X_test,Y_trainreal,Y_test=train_test_split(df,target,test_size=0.2,shuffle=True,stratify=target)
X_train,X_val,Y_train,Y_val=train_test_split(X_trainreal,Y_trainreal,test_size=0.3,shuffle=True,stratify=Y_trainreal)

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,Y_train)
prediction=logmodel.predict(X_val)
#print(classification_report(Y_val,prediction))
print(confusion_matrix(Y_val,prediction))
print(accuracy_score(Y_val,prediction))
print(f1_score(Y_val,prediction,average=None))
# Out:
# [[37  0  0]
#  [ 0 16  0]
#  [ 0  0 30]]
# 1.0
# [1. 1. 1.]

# %% [markdown]
# **So here the validation accuracy is 1. So a classifier like logistic regression can classify the dataset completely.So it is
# also a very well classifialble dataset.**

# %% [markdown]
# # RandomForestClassifier

# %%
parameters={'max_depth':[1,2,3,4,5,6],'n_estimators':[10,20,30,40,80],'ccp_alpha': [0.001,0.002,0.005,0.01,0.05,0.1]}
clf=GridSearchCV(estimator=RandomForestClassifier(),param_grid=parameters)
clf.fit(X_train,Y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'ccp_alpha': 0.002, 'max_depth': 5, 'n_estimators': 30}
# 0.9897435897435898

# %%
bestmodel=clf.best_estimator_
prediction=bestmodel.predict(X_val)
print(accuracy_score(Y_val,prediction))
print(confusion_matrix(Y_val, prediction))
print(f1_score(Y_val, prediction,average=None))
# Out:
# 0.9759036144578314
# [[36  0  1]
#  [ 0 16  0]
#  [ 1  0 29]]
# [0.97297297 1.         0.96666667]

# %% [markdown]
# **So here aslo the validation accuracy is 0.976. So Random Forest can classify the dataset completely. Also we have performed hyperparameter tuning here**

# %%
features = bestmodel.feature_importances_
vals=zip(X_train.columns,features)
vals=sorted(vals, key = lambda t: t[1],reverse=True)
lvals=list(vals)
pdf=pd.DataFrame(lvals,columns=['Features','Values'])
print(pdf)
# Out:
#                 Features    Values
# 0    Flipper Length (mm)  0.269920
# 1     Culmen Length (mm)  0.221827
# 2      Delta 13 C (o/oo)  0.159103
# 3      Culmen Depth (mm)  0.108873
# 4          Body Mass (g)  0.083313
# 5           Island_Dream  0.077581
# 6      Delta 15 N (o/oo)  0.062999
# 7       Island_Torgersen  0.009401
# 8  Clutch Completion_Yes  0.004189
# 9               Sex_MALE  0.002794

# %% [markdown]
# **As we can see 'Sex_MALE','Clutch Completion_Yes' features have extremley low importance. So as our final model we are gonna leave these 2 features as they are redundant and retrain a Logistic Regression and a RandomForestClassifier model**

# %%
temp_df = df.copy()
temp_df = temp_df.drop(['Sex_MALE','Clutch Completion_Yes'],axis=1)
temp_df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0           -0.882090           0.787030            -1.413412      -0.561634
# 1           -0.808667           0.126816            -1.057420      -0.499150
# 2           -0.661821           0.431530            -0.416635      -1.186480
# 3           -0.514975          -0.076326            -0.772626      -0.499150
# 4           -1.322628           1.091743            -0.559031      -0.936542
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)  Island_Dream  Island_Torgersen
# 0          -1.812977          -1.564680             0                 1
# 1           0.447928           1.271977             0                 1
# 2          -0.549808           0.492653             0                 1
# 3          -1.812977          -1.564680             0                 1
# 4           0.133770           0.503346             0                 1

# %%
X_trainrealtemp,X_testtemp,Y_trainrealtemp,Y_testtemp=train_test_split(temp_df,target,test_size=0.2,shuffle=True,stratify=target)
X_traintemp,X_valtemp,Y_traintemp,Y_valtemp=train_test_split(X_trainrealtemp,Y_trainrealtemp,test_size=0.3,shuffle=True,stratify=Y_trainrealtemp)

# %% [markdown]
# # Logistic Regression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_traintemp,Y_traintemp)
prediction=logmodel.predict(X_valtemp)
#print(classification_report(Y_val,prediction))
print(confusion_matrix(Y_valtemp,prediction))
print(accuracy_score(Y_valtemp,prediction))
print(f1_score(Y_valtemp,prediction,average=None))
# Out:
# [[37  0  0]
#  [ 0 16  0]
#  [ 0  0 30]]
# 1.0
# [1. 1. 1.]

# %% [markdown]
# **This is our final logistic regression model. It still has 1 accuracy score in validation dataset**

# %% [markdown]
# # RandomForestClassifier

# %%
parameters={'max_depth':[1,2,3,4,5,6],'n_estimators':[10,20,30,40,80],'ccp_alpha': [0.001,0.002,0.005,0.01,0.05,0.1]}
clf=GridSearchCV(estimator=RandomForestClassifier(),param_grid=parameters)
clf.fit(X_traintemp,Y_traintemp)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'ccp_alpha': 0.002, 'max_depth': 5, 'n_estimators': 30}
# 0.9948717948717949

# %%
bestmodel=clf.best_estimator_
prediction=bestmodel.predict(X_valtemp)
print(accuracy_score(Y_valtemp,prediction))
print(confusion_matrix(Y_valtemp, prediction))
print(f1_score(Y_valtemp, prediction,average=None))
# Out:
# 1.0
# [[37  0  0]
#  [ 0 16  0]
#  [ 0  0 30]]
# [1. 1. 1.]

# %% [markdown]
# **Here we see after giving the final RandomForestClassifierModel we can see the accuracy has slightly increased to 1. But the baseline model could not give this accuracy. So reducing features can be necessary. This is our final model.**

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# **For unsuprervised learning we have implemented our own K-Means and it is K-Means++. We will use this for initial phases**

# %%
class KMeans:
     def __init__(self, dataval,n_centers=3, init="random", distance_metric="l2", threshold=1e-4,):
        self.n_centers = n_centers
        self.threshold = threshold
        self.data = dataval # array with shape (100 samples, 2 features)
        self.centers = None # array with shape (n_centers, 2)
        self.prev_centers = None # array with shape (n_centers, 2)
        self.data_cluster = None # array with shape (100, )
        self.distances = None # array with shape (n_centers, 100)
        self.distance_metric = distance_metric
        self.init = init
        self.n_dim = None
        # self.max_iter = 1
    
     def fit(self, data):
        """ Initialize data for training
        Parameters:
        data: input features of shape (100, 2)
        """
        self.data = data
        self.n_dim = self.data.shape[-1]
        if self.init == "kmeans++":
            self.centers = self._generate_kmeans_plus_centers()
        elif self.init == "uniform":
            self.centers = self._generate_uniform_centers()
        else:
            self.centers = self._generate_random_sampled_centers()
    
     def _generate_kmeans_plus_centers(self):
        """KMeans++ initialization"""
        centers = []
        X = self.data
        Xarr=np.array(X)
        ## Sample the first point at random
        initial_index = np.random.choice(range(Xarr.shape[0]),)
        centers.append(np.asarray(X.iloc[initial_index, :].tolist()))
        ## Loop and select the remaining points
        for i in range(self.n_centers - 1):
            siz = len(centers)
            distance=[]
            for j in range(siz):
                foo = np.array(((centers[j]) - Xarr)**2)
                distance.append(foo)
            vals=np.sum(distance,axis=2)
            if i == 0:
                pdf = vals / np.sum(vals)
                centroid_new = Xarr[np.random.choice(range(Xarr.shape[0]), replace=False, p=pdf.flatten())]
            else:
                ## Calculate distance of each point from its nearest centroid
                dist_min = np.min(vals, axis=0)
                pdf = dist_min / np.sum(dist_min)
                ## Sample one point from the given prob distribution
                centroid_new = Xarr[np.random.choice(range(Xarr.shape[0]), replace=False, p=pdf.flatten())]
            centers.append(centroid_new.tolist())
        return np.array(centers)

     def _generate_uniform_centers(self):
        """Generate uniform centers"""
        centers = None
        return centers

     def _generate_random_sampled_centers(self):
        """Generate random sampled centers"""
        rand_index = None
        centers = self.data[rand_index]
        return centers

     def _l2(self, point1, point2):
        """Euclidean distance"""
        sum_sq = np.sum(np.square(point1 - point2))
        return np.sqrt(sum_sq)

     def _l1(self, point1, point2):
        """Absolute distance"""
        value=np.abs(point1-point2)
        return value

     def _calculate_distance(self):
        """Wrapper for calculating distance with data and center"""
        dist = []
        final_dist = []
        dt = np.array(self.data)
        for center in self.centers:
            if self.distance_metric == "l1":
                arrval = dt-center
                var=np.sqrt(np.sum(np.square(arrval),axis=1))
            else:
                arrval = dt-center
                var=np.sqrt(np.sum(np.square(arrval),axis=1))
            final_dist.append(var)
        self.distances = np.array(final_dist)
        return self.distances

     def _assign_clusters(self):
        """Assign each data sample to small distanced centroid"""
        self.data_cluster = np.argmin(
        self.distances, axis=0)
        # finding minimum over the the centers
        return self.data_cluster

     def _update_centers(self):  
        """Update centers with new mean among the cluster"""
        self.prev_centers = np.copy(self.centers)
        for i in range(self.n_centers):
            self.centers[i] = np.mean(
            self.data[self.data_cluster == i], axis=0
            ) # mean among the row: axis=0
        return self.centers

     def converge(self):
        """ Training convergence"""
        self._calculate_distance()
        self._assign_clusters()
        self._update_centers()
        
     def is_optimal(self):
        """ Check if the centers are optimal."""
        non_optimal = np.abs(np.sum((self.prev_centers - self.centers),axis=1)) > self.threshold
        if non_optimal.astype(int).sum() == 0:
            return True
        return False

# %%
## number of clusters
n_clusters = 3
## Noisy KMeans
kmeans_random = KMeans(X_train,n_centers=n_clusters, init="kmeans++", distance_metric="l2")
kmeans_random.fit(X_train)
print(kmeans_random.centers)
kmeans_random.converge()
while not kmeans_random.is_optimal():
    kmeans_random.converge()
print(kmeans_random.centers)
# Out:
# [[ 0.65979346 -0.17789733 -0.13184116 -0.37418068  0.66879067  0.72153882
#    1.          1.          0.          0.        ]
#  [ 0.45788012 -0.78732489  1.43452289  1.00047922 -0.57972185 -1.18542956
#    1.          0.          0.          1.        ]
#  [-0.97386902 -0.07632608 -0.91502319 -1.6238715   0.84377842 -0.0439436
#    1.          0.          1.          0.        ]]
# [[ 0.68174056  0.70422696 -0.42592137 -0.53718383  1.04801573  1.3706303
#    0.82608696  0.93478261  0.06521739  0.58695652]
#  [ 0.68786697 -1.08830442  1.20417524  1.12039441 -0.79134828 -0.47814661
#    0.91176471  0.          0.          0.52941176]
#  [-1.01152186  0.48166475 -0.76623686 -0.68259797 -0.08642476 -0.33262423
#    0.91025641  0.35897436  0.34615385  0.43589744]]

# %% [markdown]
# **Here we map the cluster labels to the target variable labels**

# %%
mydict={}
dfkmeanstrain=np.array(X_train)
targetdict=Y_train.values.ravel()
siz = len(Y_train.values)
print(siz)
lisvalreal=[]
print(np.unique(kmeans_random.data_cluster))
for lab in range(3):
    lisval=[0,0,0]
    for i in range(siz):
        val1=kmeans_random.data_cluster[i]
        if val1==lab:
            val2=targetdict[i]
            lisval[val2]=lisval[val2]+1
    lisvalreal.append(lisval)
print(lisvalreal)
# Out:
# 192
# [0 1 2]
# [[8, 38, 0], [0, 0, 68], [77, 0, 1]]

# %%
valueslist = np.argmax(lisvalreal,axis=0)
print(valueslist)
for i in range(3):
    mydict[i]=valueslist[i]
print(mydict)
# Out:
# [2 0 1]
# {0: 2, 1: 0, 2: 1}

# %% [markdown]
# **A demonstration that our K-means algorithm worked correctly in Clustering**

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X_train)
Center_pca=pca.transform(kmeans_random.centers)
cluster_list=np.unique(kmeans_random.data_cluster)
print(cluster_list)
col_list=['red','green','blue']
for i in cluster_list: 
    X_cluster1=X_pca[kmeans_random.data_cluster==i]
    plt.scatter(X_cluster1[:,0],X_cluster1[:,1],c=col_list[i])
plt.scatter(Center_pca[:,0],Center_pca[:,1],s=200,c='black')
plt.show()
# Out:
# [0 1 2]

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(X_train,kmeans_random.data_cluster, metric='euclidean')
print(score)
# Out:
# 0.39049286704271907

# %% [markdown]
# **Now here we run our K-Means model and use the dictionary to convert target variables to cluster labels**

# %%
dist = []
final_dist = []
trainkcenters=kmeans_random.centers
dkmeans=np.array(X_train)
for center in trainkcenters:
    arrval = dkmeans-center
    var=list(np.sqrt(np.sum(np.square(arrval),axis=1)))
    final_dist.append(var)
final_dist=np.array(final_dist)
print(final_dist.shape)
targetkmeans=Y_train.values.ravel()
cluster = np.argmin(np.array(final_dist), axis=0)
for i in range(len(cluster)):
    targetkmeans[i]=mydict[targetkmeans[i]]
print(cluster)
print(accuracy_score(targetkmeans,cluster))
print(classification_report(targetkmeans, cluster))
print(confusion_matrix(targetkmeans, cluster))
# Out:
# (3, 192)
# [1 2 0 1 2 0 1 0 2 2 0 2 1 1 0 0 0 1 0 0 1 2 2 0 1 2 1 2 1 2 1 2 2 2 1 1 0
#  2 2 1 2 0 1 1 1 0 1 1 0 0 2 1 2 2 2 2 0 0 2 0 1 2 1 2 2 1 2 1 2 0 1 2 1 0
#  1 0 1 2 1 2 1 1 2 2 2 1 2 0 2 1 0 0 1 1 1 0 2 2 1 1 1 0 0 2 1 0 2 2 1 0 0
#  2 1 1 2 1 1 0 0 0 2 0 0 2 1 2 2 0 1 0 1 0 1 2 2 0 2 2 0 2 0 1 2 1 2 2 2 2
#  2 0 2 2 2 2 2 2 1 1 2 1 1 2 1 1 2 1 2 2 1 1 1 2 2 2 1 1 1 0 1 2 2 2 2 0 1
#  0 1 1 2 2 0 2]
# 0.953125
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.90        38
#            1       1.00      0.99      0.99        69
#            2       0.99      0.91      0.94        85
#
#     accuracy                           0.95       192
#    macro avg       0.94      0.96      0.95       192
# weighted avg       0.96      0.95      0.95       192
#
# [[38  0  0]
#  [ 0 68  1]
#  [ 8  0 77]]

# %%
dist = []
final_dist = []
dkmeans = np.array(X_val)
kcenters=kmeans_random.centers
for center in kcenters:
    arrval = dkmeans-center
    var=list(np.sqrt(np.sum(np.square(arrval),axis=1)))
    final_dist.append(var)
final_dist=np.array(final_dist)
print(final_dist.shape)
targetvalkmeans=Y_val.values.ravel()
cluster = np.argmin(np.array(final_dist), axis=0)
for i in range(len(cluster)):
    targetvalkmeans[i]=mydict[targetvalkmeans[i]]
# finding minimum over the the centers
print(cluster)
print(accuracy_score(targetvalkmeans,cluster))
print(classification_report(targetvalkmeans, cluster))
print(confusion_matrix(targetvalkmeans, cluster))
# Out:
# (3, 83)
# [1 1 1 0 2 2 1 1 2 2 0 1 0 2 0 0 0 2 0 1 0 2 2 1 0 2 2 2 0 0 1 2 1 0 1 1 1
#  1 1 0 1 2 2 2 2 2 2 2 1 2 1 1 0 1 0 2 2 1 2 1 2 1 1 1 0 2 2 1 2 1 1 0 2 2
#  2 0 0 2 0 1 2 2 1]
# 0.9518072289156626
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89        16
#            1       1.00      1.00      1.00        30
#            2       1.00      0.89      0.94        37
#
#     accuracy                           0.95        83
#    macro avg       0.93      0.96      0.94        83
# weighted avg       0.96      0.95      0.95        83
#
# [[16  0  0]
#  [ 0 30  0]
#  [ 4  0 33]]

# %% [markdown]
# **So we can see the training accuracy is 0.953 and the test accuracy is 0.9518.**

# %% [markdown]
# # Conclusion

# %% [markdown]
# **So we can see that if our dataset can be well clustered unsupervised learning can be used for classification. Also we could see all the classifiers fully classified the dataset. So it maybe possible because it was a well classifiable dataset. In future, we would like to try this on different datasets and maybe use DBSCAN for better clustering and try the clustered labels generated by DBSCAN or other highly accurate clustering algorithms to get a better estimate**

# %% [markdown]
# # Code
# https://github.com/Abhishek0395/Penguin_Project/blob/main/Project_Penguins.ipynb
